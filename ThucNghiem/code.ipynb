# %%
import pandas as pd

file_path = r"D:\MangXaHoi\Dataset\BIOGRID-CORONAVIRUS-4.4.243.tab3.txt"

df = pd.read_csv(file_path, sep="\t", encoding="utf-8", low_memory=False)
print(df.head())  # Kiểm tra 5 dòng đầu tiên
# Out:
#    #BioGRID Interaction ID Entrez Gene Interactor A Entrez Gene Interactor B  \
# 0                   141211                   850980                   852501
# 1                   141212                   852501                   850980
# 2                   141213                   850980                   856680
# 3                   141214                   856680                   850980
# 4                   141215                   852501                   850793
#
#    BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                    31542                    32899
# 1                    32899                    31542
# 2                    31542                    36697
# 3                    36697                    31542
# 4                    32899                    31376
#
#   Systematic Name Interactor A Systematic Name Interactor B  \
# 0                      YLR274W                      YBR202W
# 1                      YBR202W                      YLR274W
# 2                      YLR274W                      YEL032W
# 3                      YEL032W                      YLR274W
# 4                      YBR202W                      YLR103C
#
#   Official Symbol Interactor A Official Symbol Interactor B  \
# 0                         MCM5                         MCM7
# 1                         MCM7                         MCM5
# 2                         MCM5                         MCM3
# 3                         MCM3                         MCM5
# 4                         MCM7                        CDC45
#
#                                Synonyms Interactor A  ...  \
# 0  BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 1  CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
# 2  BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 3   MCM DNA helicase complex subunit MCM3|L000001039  ...
# 4  CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
#
#   TREMBL Accessions Interactor B REFSEQ Accessions Interactor B  \
# 0                              -                      NP_009761
# 1                              -                      NP_013376
# 2                              -                      NP_010882
# 3                              -                      NP_013376
# 4                              -                      NP_013204
#
#   Ontology Term IDs Ontology Term Names Ontology Term Categories  \
# 0                 -                   -                        -
# 1                 -                   -                        -
# 2                 -                   -                        -
# 3                 -                   -                        -
# 4                 -                   -                        -
#
#    Ontology Term Qualifier IDs  Ontology Term Qualifier Names  \
# 0                            -                              -
# 1                            -                              -
# 2                            -                              -
# 3                            -                              -
# 4                            -                              -
#
#   Ontology Term Types        Organism Name Interactor A  \
# 0                   -  Saccharomyces cerevisiae (S288c)
# 1                   -  Saccharomyces cerevisiae (S288c)
# 2                   -  Saccharomyces cerevisiae (S288c)
# 3                   -  Saccharomyces cerevisiae (S288c)
# 4                   -  Saccharomyces cerevisiae (S288c)
#
#          Organism Name Interactor B
# 0  Saccharomyces cerevisiae (S288c)
# 1  Saccharomyces cerevisiae (S288c)
# 2  Saccharomyces cerevisiae (S288c)
# 3  Saccharomyces cerevisiae (S288c)
# 4  Saccharomyces cerevisiae (S288c)
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68578 entries, 0 to 68577
# Data columns (total 37 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   #BioGRID Interaction ID             68578 non-null  int64
#  1   Entrez Gene Interactor A            68578 non-null  object
#  2   Entrez Gene Interactor B            68578 non-null  object
#  3   BioGRID ID Interactor A             68578 non-null  int64
#  4   BioGRID ID Interactor B             68578 non-null  int64
#  5   Systematic Name Interactor A        68578 non-null  object
#  6   Systematic Name Interactor B        68578 non-null  object
#  7   Official Symbol Interactor A        68578 non-null  object
#  8   Official Symbol Interactor B        68578 non-null  object
#  9   Synonyms Interactor A               68578 non-null  object
#  10  Synonyms Interactor B               68578 non-null  object
#  11  Experimental System                 68578 non-null  object
#  12  Experimental System Type            68578 non-null  object
#  13  Author                              68578 non-null  object
#  14  Publication Source                  68578 non-null  object
#  15  Organism ID Interactor A            68578 non-null  int64
#  16  Organism ID Interactor B            68578 non-null  int64
#  17  Throughput                          68578 non-null  object
#  18  Score                               68578 non-null  object
#  19  Modification                        68578 non-null  object
#  20  Qualifications                      68578 non-null  object
#  21  Tags                                68578 non-null  object
#  22  Source Database                     68578 non-null  object
#  23  SWISS-PROT Accessions Interactor A  68578 non-null  object
#  24  TREMBL Accessions Interactor A      68578 non-null  object
#  25  REFSEQ Accessions Interactor A      68567 non-null  object
#  26  SWISS-PROT Accessions Interactor B  68578 non-null  object
#  27  TREMBL Accessions Interactor B      68578 non-null  object
#  28  REFSEQ Accessions Interactor B      68544 non-null  object
#  29  Ontology Term IDs                   68578 non-null  object
#  30  Ontology Term Names                 68578 non-null  object
#  31  Ontology Term Categories            68578 non-null  object
#  32  Ontology Term Qualifier IDs         68578 non-null  object
#  33  Ontology Term Qualifier Names       68578 non-null  object
#  34  Ontology Term Types                 68578 non-null  object
#  35  Organism Name Interactor A          68578 non-null  object
#  36  Organism Name Interactor B          68578 non-null  object
# dtypes: int64(5), object(32)
# memory usage: 19.4+ MB

# %%
df.isnull()
# Out:
#        #BioGRID Interaction ID  Entrez Gene Interactor A  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 68573                    False                     False
# 68574                    False                     False
# 68575                    False                     False
# 68576                    False                     False
# 68577                    False                     False
#
#        Entrez Gene Interactor B  BioGRID ID Interactor A  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ...                         ...                      ...
# 68573                     False                    False
# 68574                     False                    False
# 68575                     False                    False
# 68576                     False                    False
# 68577                     False                    False
#
#        BioGRID ID Interactor B  Systematic Name Interactor A  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
# ...                        ...                           ...
# 68573                    False                         False
# 68574                    False                         False
# 68575                    False                         False
# 68576                    False                         False
# 68577                    False                         False
#
#        Systematic Name Interactor B  Official Symbol Interactor A  \
# 0                             False                         False
# 1                             False                         False
# 2                             False                         False
# 3                             False                         False
# 4                             False                         False
# ...                             ...                           ...
# 68573                         False                         False
# 68574                         False                         False
# 68575                         False                         False
# 68576                         False                         False
# 68577                         False                         False
#
#        Official Symbol Interactor B  Synonyms Interactor A  ...  \
# 0                             False                  False  ...
# 1                             False                  False  ...
# 2                             False                  False  ...
# 3                             False                  False  ...
# 4                             False                  False  ...
# ...                             ...                    ...  ...
# 68573                         False                  False  ...
# 68574                         False                  False  ...
# 68575                         False                  False  ...
# 68576                         False                  False  ...
# 68577                         False                  False  ...
#
#        TREMBL Accessions Interactor B  REFSEQ Accessions Interactor B  \
# 0                               False                           False
# 1                               False                           False
# 2                               False                           False
# 3                               False                           False
# 4                               False                           False
# ...                               ...                             ...
# 68573                           False                           False
# 68574                           False                           False
# 68575                           False                           False
# 68576                           False                           False
# 68577                           False                           False
#
#        Ontology Term IDs  Ontology Term Names  Ontology Term Categories  \
# 0                  False                False                     False
# 1                  False                False                     False
# 2                  False                False                     False
# 3                  False                False                     False
# 4                  False                False                     False
# ...                  ...                  ...                       ...
# 68573              False                False                     False
# 68574              False                False                     False
# 68575              False                False                     False
# 68576              False                False                     False
# 68577              False                False                     False
#
#        Ontology Term Qualifier IDs  Ontology Term Qualifier Names  \
# 0                            False                          False
# 1                            False                          False
# 2                            False                          False
# 3                            False                          False
# 4                            False                          False
# ...                            ...                            ...
# 68573                        False                          False
# 68574                        False                          False
# 68575                        False                          False
# 68576                        False                          False
# 68577                        False                          False
#
#        Ontology Term Types  Organism Name Interactor A  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                    False                       False
# ...                    ...                         ...
# 68573                False                       False
# 68574                False                       False
# 68575                False                       False
# 68576                False                       False
# 68577                False                       False
#
#        Organism Name Interactor B
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 68573                       False
# 68574                       False
# 68575                       False
# 68576                       False
# 68577                       False
#
# [68578 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# #BioGRID Interaction ID                0
# Entrez Gene Interactor A               0
# Entrez Gene Interactor B               0
# BioGRID ID Interactor A                0
# BioGRID ID Interactor B                0
# Systematic Name Interactor A           0
# Systematic Name Interactor B           0
# Official Symbol Interactor A           0
# Official Symbol Interactor B           0
# Synonyms Interactor A                  0
# Synonyms Interactor B                  0
# Experimental System                    0
# Experimental System Type               0
# Author                                 0
# Publication Source                     0
# Organism ID Interactor A               0
# Organism ID Interactor B               0
# Throughput                             0
# Score                                  0
# Modification                           0
# Qualifications                         0
# Tags                                   0
# Source Database                        0
# SWISS-PROT Accessions Interactor A     0
# TREMBL Accessions Interactor A         0
# REFSEQ Accessions Interactor A        11
# SWISS-PROT Accessions Interactor B     0
# TREMBL Accessions Interactor B         0
# REFSEQ Accessions Interactor B        34
# Ontology Term IDs                      0
# Ontology Term Names                    0
# Ontology Term Categories               0
# Ontology Term Qualifier IDs            0
# Ontology Term Qualifier Names          0
# Ontology Term Types                    0
# Organism Name Interactor A             0
# Organism Name Interactor B             0
# dtype: int64

# %%
df.dtypes
# Out:
# #BioGRID Interaction ID                int64
# Entrez Gene Interactor A              object
# Entrez Gene Interactor B              object
# BioGRID ID Interactor A                int64
# BioGRID ID Interactor B                int64
# Systematic Name Interactor A          object
# Systematic Name Interactor B          object
# Official Symbol Interactor A          object
# Official Symbol Interactor B          object
# Synonyms Interactor A                 object
# Synonyms Interactor B                 object
# Experimental System                   object
# Experimental System Type              object
# Author                                object
# Publication Source                    object
# Organism ID Interactor A               int64
# Organism ID Interactor B               int64
# Throughput                            object
# Score                                 object
# Modification                          object
# Qualifications                        object
# Tags                                  object
# Source Database                       object
# SWISS-PROT Accessions Interactor A    object
# TREMBL Accessions Interactor A        object
# REFSEQ Accessions Interactor A        object
# SWISS-PROT Accessions Interactor B    object
# TREMBL Accessions Interactor B        object
# REFSEQ Accessions Interactor B        object
# Ontology Term IDs                     object
# Ontology Term Names                   object
# Ontology Term Categories              object
# Ontology Term Qualifier IDs           object
# Ontology Term Qualifier Names         object
# Ontology Term Types                   object
# Organism Name Interactor A            object
# Organism Name Interactor B            object
# dtype: object

# %%
import pandas as pd

# Đọc file TXT (thay đổi đường dẫn cho phù hợp)
file_path =  r"D:\MangXaHoi\Dataset\BIOGRID-CORONAVIRUS-4.4.243.tab3.txt"
df = pd.read_csv(file_path, sep="\t", encoding="utf-8", low_memory=False)

# Lưu file dưới dạng CSV
csv_path = "D:\MangXaHoi\Dataset\BIOGRID-CORONAVIRUS.csv"
df.to_csv(csv_path, index=False)

print(f"File đã được lưu thành CSV tại: {csv_path}")
# Out:
# File đã được lưu thành CSV tại: D:\MangXaHoi\Dataset\BIOGRID-CORONAVIRUS.csv

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in d:\python_3_10\lib\site-packages (3.4.2)
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Đọc file CSV
file_path = r"D:\MangXaHoi\Dataset\BIOGRID-CORONAVIRUS.csv"
df = pd.read_csv(file_path, encoding="utf-8", low_memory=False)

# Xem 5 dòng đầu tiên để kiểm tra dữ liệu
df.head()
# Out:
#    #BioGRID Interaction ID Entrez Gene Interactor A Entrez Gene Interactor B  \
# 0                   141211                   850980                   852501
# 1                   141212                   852501                   850980
# 2                   141213                   850980                   856680
# 3                   141214                   856680                   850980
# 4                   141215                   852501                   850793
#
#    BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                    31542                    32899
# 1                    32899                    31542
# 2                    31542                    36697
# 3                    36697                    31542
# 4                    32899                    31376
#
#   Systematic Name Interactor A Systematic Name Interactor B  \
# 0                      YLR274W                      YBR202W
# 1                      YBR202W                      YLR274W
# 2                      YLR274W                      YEL032W
# 3                      YEL032W                      YLR274W
# 4                      YBR202W                      YLR103C
#
#   Official Symbol Interactor A Official Symbol Interactor B  \
# 0                         MCM5                         MCM7
# 1                         MCM7                         MCM5
# 2                         MCM5                         MCM3
# 3                         MCM3                         MCM5
# 4                         MCM7                        CDC45
#
#                                Synonyms Interactor A  ...  \
# 0  BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 1  CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
# 2  BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 3   MCM DNA helicase complex subunit MCM3|L000001039  ...
# 4  CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
#
#   TREMBL Accessions Interactor B REFSEQ Accessions Interactor B  \
# 0                              -                      NP_009761
# 1                              -                      NP_013376
# 2                              -                      NP_010882
# 3                              -                      NP_013376
# 4                              -                      NP_013204
#
#   Ontology Term IDs Ontology Term Names Ontology Term Categories  \
# 0                 -                   -                        -
# 1                 -                   -                        -
# 2                 -                   -                        -
# 3                 -                   -                        -
# 4                 -                   -                        -
#
#    Ontology Term Qualifier IDs  Ontology Term Qualifier Names  \
# 0                            -                              -
# 1                            -                              -
# 2                            -                              -
# 3                            -                              -
# 4                            -                              -
#
#   Ontology Term Types        Organism Name Interactor A  \
# 0                   -  Saccharomyces cerevisiae (S288c)
# 1                   -  Saccharomyces cerevisiae (S288c)
# 2                   -  Saccharomyces cerevisiae (S288c)
# 3                   -  Saccharomyces cerevisiae (S288c)
# 4                   -  Saccharomyces cerevisiae (S288c)
#
#          Organism Name Interactor B
# 0  Saccharomyces cerevisiae (S288c)
# 1  Saccharomyces cerevisiae (S288c)
# 2  Saccharomyces cerevisiae (S288c)
# 3  Saccharomyces cerevisiae (S288c)
# 4  Saccharomyces cerevisiae (S288c)
#
# [5 rows x 37 columns]

# %%
# Tạo đồ thị
G = nx.Graph()

# Thêm cạnh từ dữ liệu
for _, row in df.iterrows():
    G.add_edge(row["Official Symbol Interactor A"], row["Official Symbol Interactor B"])

# Thông tin về đồ thị
print(f"Số nút (protein): {G.number_of_nodes()}")
print(f"Số cạnh (mối quan hệ tương tác): {G.number_of_edges()}")
# Out:
# Số nút (protein): 8498
# Số cạnh (mối quan hệ tương tác): 48090

# %%
# Tạo đồ thị
G = nx.Graph()

# Thêm cạnh vào đồ thị
for _, row in df.iterrows():
    G.add_edge(row["Official Symbol Interactor A"], row["Official Symbol Interactor B"])

# Tính độ trung tâm của các nút
#Độ trung tâm (Degree Centrality) là một chỉ số đo tầm quan trọng của một nút (protein) trong mạng bằng cách đếm số lượng kết nối (edges) của nó với các nút khác.
degree_centrality = nx.degree_centrality(G)

# Chọn top 20 protein quan trọng nhất---degree_centrality.get giúp sắp xếp dictionary theo giá trị thay vì key.
top_nodes = sorted(degree_centrality, key=degree_centrality.get, reverse=True)[:20]

# Tạo đồ thị con chứa 50 protein này
G_sub = G.subgraph(top_nodes)

# Vẽ đồ thị
plt.figure(figsize=(12, 8))
nx.draw(G_sub, with_labels=True, node_size=500, node_color="orange", edge_color="black", font_size=8)
plt.title("Mạng lưới tương tác của 20 protein quan trọng nhất")
plt.show()

# %%
# 2. Chọn cột chứa các tương tác
edges = df[['Official Symbol Interactor A', 'Official Symbol Interactor B']].dropna()

# %%
# 3. Tạo đồ thị mạng
G = nx.Graph()
G.add_edges_from(edges.values)

# 4. Tính bậc của mỗi nút
degree_sequence = [d for n, d in G.degree()]

# %%
# 5. Vẽ biểu đồ phân phối bậc (Degree Distribution)
plt.figure(figsize=(8,6))
plt.hist(degree_sequence, bins=30, color='skyblue', edgecolor='black', log=True)
plt.xlabel("Degree (Số liên kết)", fontsize=12)
plt.ylabel("Số lượng protein", fontsize=12)
plt.title("Phân phối bậc của nút (Degree Distribution)", fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
# 2. Chọn cột chứa các tương tác
edges = df[['Official Symbol Interactor A', 'Official Symbol Interactor B']].dropna()

# 3. Tạo đồ thị mạng
G = nx.Graph()
G.add_edges_from(edges.values)

# 4. Tính Betweenness Centrality
betweenness = nx.betweenness_centrality(G)

# 5. Tính Closeness Centrality
closeness = nx.closeness_centrality(G)

# 6. Sắp xếp các protein quan trọng nhất
top_betweenness = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)[:10]
top_closeness = sorted(closeness.items(), key=lambda x: x[1], reverse=True)[:10]

# 7. Hiển thị kết quả
print("Top 10 Protein theo Betweenness Centrality:")
for protein, value in top_betweenness:
    print(f"{protein}: {value:.5f}")

print("\nTop 10 Protein theo Closeness Centrality:")
for protein, value in top_closeness:
    print(f"{protein}: {value:.5f}")
# Out:
# Top 10 Protein theo Betweenness Centrality:
# S: 0.16138
# M: 0.12611
# N: 0.10796
# ORF7b: 0.07674
# nsp9: 0.06910
# TGOLN2: 0.06515
# ORF3a: 0.06467
# ORF8: 0.06141
# E: 0.05384
# nsp6: 0.04841
#
# Top 10 Protein theo Closeness Centrality:
# M: 0.54114
# S: 0.51845
# N: 0.51585
# ORF7a: 0.50146
# ORF3a: 0.50105
# E: 0.50007
# ORF7b: 0.49806
# nsp4: 0.49444
# ORF8: 0.49363
# ORF6: 0.47948

# %%
import seaborn as sns
centrality_df = pd.DataFrame({
    "Protein": list(degree_centrality.keys()),
    "Degree Centrality": list(degree_centrality.values()),
    "Betweenness Centrality": list(betweenness.values()),
    "Closeness Centrality": list(closeness.values())
})

# 6. Chọn Top 20 protein có Degree Centrality cao nhất
top_proteins = centrality_df.sort_values(by="Degree Centrality", ascending=False).head(20)

# 7. Vẽ heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(top_proteins.set_index("Protein"), annot=True, cmap="coolwarm", linewidths=0.5)
plt.title("Heatmap của Degree, Betweenness và Closeness Centrality")
plt.show()

# %% [markdown]
# S và M có Degree Centrality cao nhất (0.28) → Chúng có nhiều kết nối nhất trong mạng, cho thấy vai trò quan trọng trong sự lây lan tín hiệu.
#
# M có Closeness Centrality cao nhất (0.54), theo sau là S (0.52) → Hai protein này có thể truyền tín hiệu nhanh trong mạng.
#
# Betweenness Centrality thấp hơn so với các chỉ số khác → Điều này có thể do mạng có nhiều con đường kết nối khác nhau, giảm sự phụ thuộc vào một số protein làm "cầu nối".
#
# ORF7b, ORF3a, E, nsp6 cũng có mức Closeness Centrality cao → Những protein này có thể có vai trò hỗ trợ quan trọng trong hệ thống.

# %%
print(df['Experimental System Type'].unique())
# Out:
# ['physical' 'genetic']

# %%
# Phân loại theo 'Experimental System Type'
df["Interaction Class"] = df["Experimental System Type"].apply(
    lambda x: "Physical Interaction" if x == "physical" else "Genetic Interaction"
)

# Hiển thị 10 dòng đầu
print(df[["Experimental System Type", "Interaction Class"]].head(20))
# Out:
#    Experimental System Type     Interaction Class
# 0                  physical  Physical Interaction
# 1                  physical  Physical Interaction
# 2                  physical  Physical Interaction
# 3                  physical  Physical Interaction
# 4                  physical  Physical Interaction
# 5                  physical  Physical Interaction
# 6                  physical  Physical Interaction
# 7                  physical  Physical Interaction
# 8                  physical  Physical Interaction
# 9                   genetic   Genetic Interaction
# 10                  genetic   Genetic Interaction
# 11                  genetic   Genetic Interaction
# 12                 physical  Physical Interaction
# 13                 physical  Physical Interaction
# 14                 physical  Physical Interaction
# 15                 physical  Physical Interaction
# 16                 physical  Physical Interaction
# 17                 physical  Physical Interaction
# 18                 physical  Physical Interaction
# 19                 physical  Physical Interaction
